# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %% [markdown]
# # Import data

# %%
# we are going to use internal seaborn dataset

#print(sns.get_dataset_names())

tips_df = sns.load_dataset('tips')

tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#sns bar plot

sns.barplot(x = 'day' , y= 'total_bill', data =tips_df )

# %%
#hue attribute : to divide by category

#sns bar plot

sns.barplot(x = 'day' , y= 'total_bill', hue = 'sex',data =tips_df )

# %%
#to change the order of day

sns.barplot(x = 'day' , y= 'total_bill', hue = 'sex',order = ['Sun','Sat','Thur','Fri'],data =tips_df )

# %%
#to change the order of day

sns.barplot(x = 'day' , y= 'total_bill', hue = 'sex',data =tips_df,order = ['Sun','Sat','Thur','Fri']
            ,palette ='deep' )

# %%
#horizontal bar

sns.barplot(x="tip", y="day", data=tips_df)

# %%
#These small small bars in top are 'error bars'

# %%
# we can adjust confidence invertal 

sns.barplot(x = 'day' , y= 'total_bill', hue = 'sex',data =tips_df,order = ['Sun','Sat','Thur','Fri']
            ,palette ='deep' ,ci = 95)

# %%
sns.barplot(x = 'day' , y= 'total_bill', hue = 'sex',data =tips_df,order = ['Sun','Sat','Thur','Fri']
            ,palette ='deep' ,ci = 95,capsize = 0.1)

# %%
# Use catplot() to combine a barplot() and a FacetGrid. This allows grouping within additional 
# categorical variables. Using catplot() is safer than using FacetGrid directly,
# as it ensures synchronization of variable order across facets:

sns.catplot(x = 'day' , y= 'total_bill', hue = 'sex',data =tips_df,kind= 'bar',col='smoker')

# %%
sns.catplot(x = 'day' , y= 'total_bill', hue = 'sex',data =tips_df,kind= 'bar',col='smoker',aspect=.7,height=4)

# %% [markdown]
# # Count plot

# %%
sns.countplot(x='sex',data=tips_df)  # how many male and female

# %%
sns.countplot(x='sex',data=tips_df,hue='smoker') #count for male and female under smoker catergory

# %%
sns.countplot(x='sex',data=tips_df,hue='time')

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x='day',y='total_bill',data=tips_df,hue = 'sex')

plt.legend(loc=(1,0.5))

# %% [markdown]
# # Strip plot

# %%
sns.stripplot(x='day',y='total_bill',data= tips_df)

# %%
sns.stripplot(x='day',y='total_bill',data= tips_df,hue='sex')
plt.legend(loc=(1,0))

# %%
plt.figure(figsize= (10,5))
sns.stripplot(x='day',y='total_bill',data= tips_df,hue='sex',jitter= True)
plt.legend(loc=(1,0))

# %%
plt.figure(figsize= (10,5))
sns.stripplot(x='day',y='total_bill',data= tips_df,hue='sex',jitter= True,dodge=True)
plt.legend(loc=(1,0))

# %%
plt.figure(figsize= (10,5))
sns.stripplot(x='day',y='total_bill',data= tips_df,hue='sex',jitter= True,dodge=True,size = 4,palette= 'deep')
plt.legend(loc=(1,0))

# %%
plt.figure(figsize= (10,5))
sns.set_style('dark')
sns.stripplot(x='day',y='total_bill',data= tips_df,hue='sex',jitter= True,dodge=True,size = 4,palette= 'magma')
plt.legend(loc=(1,0))

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights1 = flights.pivot_table(index = 'month',columns = 'year',values='passengers')
flights1
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
plt.figure(figsize=(10,4))
sns.heatmap(data = flights1,cmap='Blues',linecolor='white',linewidth=0.01)

# %%
#in heat map we can read that in month of june,july and aug no. of flights is more with respect to time

# %% [markdown]
# # 1.Numerical Data plotting
#
#     *relplot()
#     *Scatterplot()
#     *lineplot()
#
# # 2.Categorical Data plotting
#
#     *catplot()
#     *barplot()
#     *boxplot()
#     *swarmplot()
#     *stripplot()
#     *countplot()
#     *etc....
#
# # 3.Visvualizing Distribution of Data
#
#     *distplot()
#     *jointplot()
#     *kdeplot()
#     *rugplot()
#
# # 4.Liner Regression and Relationship
#
#     *regplot()
#     *implot()

# %% [markdown]
# # seaborn.relplot
#
# seaborn.relplot(*, x=None, y=None, hue=None, size=None, style=None, data=None, row=None, col=None, col_wrap=None, row_order=None, col_order=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=None, dashes=None, style_order=None, legend='auto', kind='scatter', height=5, aspect=1, facet_kws=None, units=None, **kwargs)¶
#
#     Figure-level interface for drawing relational plots onto a FacetGrid.
#
#     This function provides access to several different axes-level functions that show the relationship between two variables with semantic mappings of subsets. The kind parameter selects the underlying axes-level function to use:
#
#         scatterplot() (with kind="scatter"; the default)
#
#         lineplot() (with kind="line")
#
#
# For more details : https://seaborn.pydata.org/generated/seaborn.relplot.html

# %%
#setting sns stype

sns.set(style='darkgrid',palette='deep')

# %%
#dataset 

tips = sns.load_dataset('tips')

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Relation between order total and tip given to waiter on that order

sns.relplot(x = 'total_bill',y='tip',data= tips)

# %%
#We can see the linear relationship b/w total_bill and tip.

sns.relplot(x = 'total_bill',y='tip',data= tips,hue='smoker') # divide the category

# %%
tips['smoker'].value_counts()   # non-smoker is more
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
gp = tips.groupby('smoker')['tip','total_bill'].agg(['sum','count','mean','median'])
gp
# Out:
#            tip                        total_bill
#            sum count      mean median        sum count       mean median
# smoker
# Yes     279.81    93  3.008710   3.00    1930.34    93  20.756344  17.92
# No      451.77   151  2.991854   2.74    2897.43   151  19.188278  17.59

# %%
#but we can see the on average smoker is giving more tip

# %%
sns.relplot(x = 'total_bill',y='tip',data= tips,hue='sex')

#hue :Grouping variable that will produce elements with different colors. 
#Can be either categorical or numeric, although color mapping will behave differently in latter case.

# %%
sns.relplot(x = 'total_bill',y='tip',data= tips,size='sex')

# size: Grouping variable that will produce elements with different sizes. 
#Can be either categorical or numeric, although size mapping will behave differently in latter case.

# %%
sns.relplot(x = 'total_bill',y='tip',data= tips,size='sex',sizes = (100,200))

# %%
sns.relplot(x = 'total_bill',y='tip',data= tips,style='sex')

#style: Grouping variable that will produce elements with different styles. 
#Can have a numeric dtype but will always be treated as categorical.

# %%
sns.relplot(y = 'total_bill',x='day',data= tips,kind = 'line')

# %%
sns.relplot(y = 'total_bill',x='tip',data= tips,col='time')

# %%
sns.relplot(y = 'total_bill',x='tip',data= tips,row='time')

# %%
sns.relplot(y = 'total_bill',x='tip',data= tips,col='time',row='sex')

# %%
#lol sometime male gives more tips at dinner time

# %%
sns.relplot(y = 'total_bill',x='day',data= tips,kind = 'line',ci= None,estimator= None,hue='time')

#without confidence interval(95%) without estimator(real dataset points)

# %%
sns.relplot(y = 'total_bill',x='day',data= tips,kind = 'line',hue='time',style ='time',ci=None,estimator=None)

# %%
#diving into columns for each day
sns.relplot(data=tips, x="total_bill", y="tip", hue="time", col="day")

# %%
#lets divide into two columns
sns.relplot(data=tips, x="total_bill", y="tip", hue="time", col="day", col_wrap=2)

# %%
#setting title , axis label

g = sns.relplot(data=tips, x="total_bill", y="tip", hue="time")

plt.title('A')
# Out:
# Text(0.5, 1, 'A')

# %%
#lets create some dataframe

df = pd.DataFrame(dict(time =pd.date_range('2020-01-01',periods = 500),value = np.random.randn(500).cumsum()))

df.head()
# Out:
#         time     value
# 0 2020-01-01  0.202393
# 1 2020-01-02 -0.555136
# 2 2020-01-03  0.515758
# 3 2020-01-04  1.078201
# 4 2020-01-05  0.237837

# %%
df.tail()
# Out:
#           time      value
# 495 2021-05-10 -12.823325
# 496 2021-05-11 -10.790939
# 497 2021-05-12 -11.395094
# 498 2021-05-13 -10.805380
# 499 2021-05-14  -9.954638

# %%
#line chart
sns.relplot(x='time',y= 'value',data = df,kind='line')

# %%
#we can't see the date part clearly lets fix this

g = sns.relplot(x='time',y= 'value',data = df,kind='line')

g.fig.autofmt_xdate()

# %%
# #note :
# The object returned by relplot() is always a FacetGrid, which has several methods that allow you to quickly
# tweak the title, labels, and other aspects of the plot

# %%
#Categrical visualization

# %%
titanic = sns.load_dataset('titanic')

titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # seaborn.catplot
#
# seaborn.catplot(*, x=None, y=None, hue=None, data=None, row=None, col=None, col_wrap=None, estimator=<function mean at 0x7fa4c4f67940>, ci=95, n_boot=1000, units=None, seed=None, order=None, hue_order=None, row_order=None, col_order=None, kind='strip', height=5, aspect=1, orient=None, color=None, palette=None, legend=True, legend_out=True, sharex=True, sharey=True, margin_titles=False, facet_kws=None, **kwargs)
#
#     Figure-level interface for drawing categorical plots onto a FacetGrid.
#
#     This function provides access to several axes-level functions that show the relationship between a numerical and one or more categorical variables using one of several visual representations. The kind parameter selects the underlying axes-level function to use:
#
#     Categorical scatterplots:
#
#         stripplot() (with kind="strip"; the default)
#
#         swarmplot() (with kind="swarm")
#
#     Categorical distribution plots:
#
#         boxplot() (with kind="box")
#
#         violinplot() (with kind="violin")
#
#         boxenplot() (with kind="boxen")
#
#     Categorical estimate plots:
#
#         pointplot() (with kind="point")
#
#         barplot() (with kind="bar")
#
#         countplot() (with kind="count")
#
#
# for additional info: https://seaborn.pydata.org/generated/seaborn.catplot.html
#
# Facet grid doc: https://seaborn.pydata.org/generated/seaborn.FacetGrid.html#seaborn.FacetGrid

# %%
sns.catplot(x='total_bill',y='tip',data = tips)

#we can see that categorical plot is not good to represent two numberical relation,les try with cat field

# %%
sns.catplot(x='day',y='tip',data = tips)

# %%
#so its means for catplot() one field should be categorical

# %%
sns.catplot(x='smoker',y='tip',data = tips,order= ['No','Yes'])

# %%
#we can create each type of categorical vis with catplot()

sns.catplot(x='day',y='total_bill',data= tips,kind= 'box',hue='time')

# %%
#people usually spend more on weekends at dinner time

# %%
# cat vs cat

sns.catplot(x= 'sex',y= 'survived',data= titanic,kind= 'bar',hue= 'class')

# %%
#above we can see the survial rate veries with class with respect to sex

#note the small small lines on the top of bars is error bars which shows confidence interval.

# %%
sns.catplot(x= 'sex',y= 'survived',data= titanic,kind= 'point',hue= 'class')

# %%
sns.catplot(x= 'sex',data= titanic,kind= 'count',col='class')

# %%
# Distribution of data viz

# %%
x = np.random.randn(100)

# %%
sns.distplot(x)

# %%
sns.distplot(x,bins= 30,hist=False)

# %%
sns.distplot(x,bins= 30,hist=False,kde = False,rug=True)

# %%
sns.distplot(x,bins= 30,hist=True,kde = False)

# %%
sns.jointplot(x='total_bill',y='tip',data= tips,color= 'red')

# %%
sns.jointplot(x='total_bill',y='tip',data= tips,color= 'red',kind="reg")

# %%
sns.pairplot(data=tips)

# %%
sns.regplot(x='total_bill',y='tip',data=tips)

# %%
#it shows relation between order_bill and waiter tip
