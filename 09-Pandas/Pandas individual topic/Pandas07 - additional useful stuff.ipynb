# %%
import pandas as pd

# %%
#How we can read only required columns while reading the data so that we can avoid other chunk while reading itself


movies = pd.read_csv('http://bit.ly/imdbratings')

movies.columns  #to check the column names only here
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
#Now lets call only three columns while reading itself 

movies1 = pd.read_csv('http://bit.ly/imdbratings',usecols=['star_rating','title','genre'])

movies1.head()
# Out:
#    star_rating                     title   genre
# 0          9.3  The Shawshank Redemption   Crime
# 1          9.2             The Godfather   Crime
# 2          9.1    The Godfather: Part II   Crime
# 3          9.0           The Dark Knight  Action
# 4          8.9              Pulp Fiction   Crime

# %%
#Ta da we got dataframe with required columns only

# %%
# Now lets assume our data is very huge and before importing data we want to explore our data and wanted to grab
#only few rows to check the data..... let see how we can do that


movies2 = pd.read_csv('http://bit.ly/imdbratings',nrows = 10)
movies2
# Out:
#    star_rating                                          title content_rating  \
# 0          9.3                       The Shawshank Redemption              R
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# ...

# %%
#we can use loop to get specifc columns to


for index,col in movies2.iterrows():
    print(index,col.star_rating,col.title)
# Out:
# 0 9.3 The Shawshank Redemption
# 1 9.2 The Godfather
# 2 9.1 The Godfather: Part II
# 3 9.0 The Dark Knight
# 4 8.9 Pulp Fiction
# 5 8.9 12 Angry Men
# 6 8.9 The Good, the Bad and the Ugly
# 7 8.9 The Lord of the Rings: The Return of the King
# 8 8.9 Schindler's List
# 9 8.9 Fight Club

# %%
movies3 = movies[movies['title'].str.contains('Man')]   #dataframe with title which has Man substring in it

# %%
movies3.head(20)
# Out:
#      star_rating                             title content_rating      genre  \
# 105          8.3                     The Third Man      NOT RATED  Film-Noir
# 148          8.2                  The Elephant Man             PG  Biography
# 235          8.1                           Yip Man              R     Action
# 251          8.1  The Man Who Shot Liberty Valance       APPROVED      Drama
# 292          8.1          The Manchurian Candidate       APPROVED    Mystery
# 319          8.0                         Manhattan              R     Comedy
# 325          8.0                          Rain Man              R      Drama
# 341          8.0                    Cinderella Man          PG-13  Biography
# 345          8.0                     No Man's Land              R      Drama
# 420          7.9         The Man Who Would Be King             PG     Action
# 434          7.9                          Iron Man          PG-13     Action
# ...

# %%
movies3.loc[0:,'actors_list'] = movies3['actors_list'].str.replace('[','(').str.replace(']',')')

# %%
movies3.head()  # you will notice that now star square brackets gets changed into normal brackets
# Out:
#      star_rating                             title content_rating      genre  \
# 105          8.3                     The Third Man      NOT RATED  Film-Noir
# 148          8.2                  The Elephant Man             PG  Biography
# 235          8.1                           Yip Man              R     Action
# 251          8.1  The Man Who Shot Liberty Valance       APPROVED      Drama
# 292          8.1          The Manchurian Candidate       APPROVED    Mystery
#
#      duration                                        actors_list
# 105        93  (u'Orson Welles', u'Joseph Cotten', u'Alida Va...
# 148       124  (u'Anthony Hopkins', u'John Hurt', u'Anne Banc...
# 235       106     (u'Donnie Yen', u'Simon Yam', u'Siu-Wong Fan')
# 251       123   (u'James Stewart', u'John Wayne', u'Vera Miles')
# 292       126  (u'Frank Sinatra', u'Laurence Harvey', u'Janet...
