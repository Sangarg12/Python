# %%
import pandas as pd

# %%
movie = pd.read_csv('http://bit.ly/imdbratings')

movie.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movie.shape
# Out:
# (979, 6)

# %%
movie.index   # this will give us the index value range
# Out:
# RangeIndex(start=0, stop=979, step=1)

# %%
movie.columns   # to get columns names, remember columns are not part of dateset
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
#to get range of columns

movie.loc[10:15]   # to get specfic range of rows by index
# Out:
#     star_rating                                              title  \
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 11          8.8                                          Inception
# 12          8.8     Star Wars: Episode V - The Empire Strikes Back
# 13          8.8                                       Forrest Gump
# 14          8.8              The Lord of the Rings: The Two Towers
# 15          8.7                                       Interstellar
#
#    content_rating      genre  duration  \
# 10          PG-13  Adventure       178
# 11          PG-13     Action       148
# 12             PG     Action       124
# 13          PG-13      Drama       142
# 14          PG-13  Adventure       179
# 15          PG-13  Adventure       169
#
#                                           actors_list
# 10  [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# 11  [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# ...

# %%
#if we don't like numerical index we can set it to other column as well as per our convenience



movie.set_index('genre',inplace=True)

# %%
movie.head()  # we can see that now genre is set as index now
# Out:
#         star_rating                     title content_rating  duration  \
# genre
# Crime           9.3  The Shawshank Redemption              R       142
# Crime           9.2             The Godfather              R       175
# Crime           9.1    The Godfather: Part II              R       200
# Action          9.0           The Dark Knight          PG-13       152
# Crime           8.9              Pulp Fiction              R       154
#
#                                               actors_list
# genre
# Crime   [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# Crime     [u'Marlon Brando', u'Al Pacino', u'James Caan']
# Crime   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# Action  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# Crime   [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
 movie.loc['Action']  # only rows will come with index as 'Action'
# Out:
#         star_rating                                            title  \
# genre
# Action          9.0                                  The Dark Knight
# Action          8.8                                        Inception
# Action          8.8   Star Wars: Episode V - The Empire Strikes Back
# Action          8.7                                        Star Wars
# Action          8.7                                       The Matrix
# ...             ...                                              ...
# Action          7.5                                   Running Scared
# Action          7.4                                            X-Men
# Action          7.4                                  La Femme Nikita
# Action          7.4                                         The Rock
# Action          7.4  Master and Commander: The Far Side of the World
#
#        content_rating  duration  \
# genre
# Action          PG-13       152
# Action          PG-13       148
# ...

# %%
# we can reset are index too if want to change it later back to original

movie.reset_index(inplace=True)

# %%
movie.head()
# Out:
#     genre  star_rating                     title content_rating  duration  \
# 0   Crime          9.3  The Shawshank Redemption              R       142
# 1   Crime          9.2             The Godfather              R       175
# 2   Crime          9.1    The Godfather: Part II              R       200
# 3  Action          9.0           The Dark Knight          PG-13       152
# 4   Crime          8.9              Pulp Fiction              R       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movie.index # now index are back to orignal
# Out:
# RangeIndex(start=0, stop=979, step=1)

# %%
movie.columns
# Out:
# Index(['genre', 'star_rating', 'title', 'content_rating', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
movie.index.name ='Sr. No.'
movie.head()
# Out:
#           genre  star_rating                     title content_rating  \
# Sr. No.
# 0         Crime          9.3  The Shawshank Redemption              R
# 1         Crime          9.2             The Godfather              R
# 2         Crime          9.1    The Godfather: Part II              R
# 3        Action          9.0           The Dark Knight          PG-13
# 4         Crime          8.9              Pulp Fiction              R
#
#          duration                                        actors_list
# Sr. No.
# 0             142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1             175    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2             200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3             152  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4             154  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
# you can see that now is appear to the index column, we can give any name

#we don't want index name we can remove it too

movie.index.name = None
movie.head(10)
# Out:
#        genre  star_rating                                          title  \
# 0      Crime          9.3                       The Shawshank Redemption
# 1      Crime          9.2                                  The Godfather
# 2      Crime          9.1                         The Godfather: Part II
# 3     Action          9.0                                The Dark Knight
# 4      Crime          8.9                                   Pulp Fiction
# 5      Drama          8.9                                   12 Angry Men
# 6    Western          8.9                 The Good, the Bad and the Ugly
# 7  Adventure          8.9  The Lord of the Rings: The Return of the King
# 8  Biography          8.9                               Schindler's List
# 9      Drama          8.9                                     Fight Club
#
#   content_rating  duration                                        actors_list
# 0              R       142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# ...

# %%
#we can sort index in acending or decending, its already in acending lets try with decending

movie.sort_index(ascending = False)
# Out:
#          genre  star_rating                                            title  \
# 978      Crime          7.4                                      Wall Street
# 977     Horror          7.4                                      Poltergeist
# 976     Action          7.4  Master and Commander: The Far Side of the World
# 975  Adventure          7.4                      Back to the Future Part III
# 974     Comedy          7.4                                          Tootsie
# ..         ...          ...                                              ...
# 4        Crime          8.9                                     Pulp Fiction
# 3       Action          9.0                                  The Dark Knight
# 2        Crime          9.1                           The Godfather: Part II
# 1        Crime          9.2                                    The Godfather
# 0        Crime          9.3                         The Shawshank Redemption
#
#     content_rating  duration  \
# ...
